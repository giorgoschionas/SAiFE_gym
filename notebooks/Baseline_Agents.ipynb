# %%
import sys
sys.path.append("../") # This version of the notebook is in the subfolder "notebooks" of the repo

import gym
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from copy import deepcopy
import torch

# %%
from gym.LiquidityProvisionEnvironment import LiquidityProvisionEnvironment
from agents.BaselineAgents import ActiveLPAgent, MovingAverageLPAgent, RandomAgent

# %% [markdown]
# ## Random strategy

# %%
terminal_time = 1.0
n_steps = 200
seed = 42 
np.random.seed(seed)
timestamps = np.linspace(0, terminal_time, n_steps + 1)

env = LiquidityProvisionEnvironment(terminal_time=terminal_time, n_steps=n_steps, seed=seed)
random = RandomAgent(env,seed=seed)
